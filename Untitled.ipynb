# %%
import pandas as pd

savant2018 = pd.read_csv('D://statcast//savant2018.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
savant2018.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2018-03-29           96.7        -1.3857         6.1136
# 1         SI  2018-03-29           96.0        -1.3302         6.1877
# 2         FF  2018-03-29           98.1        -1.3381         5.9711
# 3         FF  2018-03-29           97.4        -1.1546         5.9254
# 4         FF  2018-03-29           97.1        -1.1802         6.0784
#
#       player_name    batter   pitcher     events    description  \
# 0  Jeurys Familia  657557.0  544727.0  field_out  hit_into_play
# 1  Jeurys Familia  657557.0  544727.0        NaN   blocked_ball
# 2  Jeurys Familia  425877.0  544727.0       walk           ball
# 3  Jeurys Familia  425877.0  544727.0        NaN           ball
# 4  Jeurys Familia  425877.0  544727.0        NaN           ball
#
#            ...           home_score  away_score  bat_score  fld_score  \
# 0          ...                  9.0         4.0        4.0        9.0
# ...

# %%
sam = savant2018[savant2018.player_name == 'Jeurys Familia']

# %%
sam.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2018-03-29           96.7        -1.3857         6.1136
# 1         SI  2018-03-29           96.0        -1.3302         6.1877
# 2         FF  2018-03-29           98.1        -1.3381         5.9711
# 3         FF  2018-03-29           97.4        -1.1546         5.9254
# 4         FF  2018-03-29           97.1        -1.1802         6.0784
#
#       player_name    batter   pitcher     events    description  \
# 0  Jeurys Familia  657557.0  544727.0  field_out  hit_into_play
# 1  Jeurys Familia  657557.0  544727.0        NaN   blocked_ball
# 2  Jeurys Familia  425877.0  544727.0       walk           ball
# 3  Jeurys Familia  425877.0  544727.0        NaN           ball
# 4  Jeurys Familia  425877.0  544727.0        NaN           ball
#
#            ...           home_score  away_score  bat_score  fld_score  \
# 0          ...                  9.0         4.0        4.0        9.0
# ...

# %%
sam.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
samcol = sam[['pitch_type', 'release_speed', 'release_spin_rate', 'release_extension']]
samcol.head()
# Out:
#   pitch_type  release_speed  release_spin_rate  release_extension
# 0         SI           96.7             2307.0              5.574
# 1         SI           96.0             2399.0              5.527
# 2         FF           98.1             2278.0              6.122
# 3         FF           97.4             2217.0              5.910
# 4         FF           97.1             2167.0              5.407

# %%
samcol.groupby('pitch_type').mean()
# Out:
#             release_speed  release_spin_rate  release_extension
# pitch_type
# FF              96.477473        2256.252747           5.752676
# FS              91.686486        1729.405405           5.520946
# SI              96.053365        2219.200313           5.730872
# SL              87.880175        2286.358601           5.385320

# %%
plate = sam[['plate_x', 'plate_z']]

# %%
top = sam['sz_top'].mean()
bot = sam['sz_bot'].mean()
ft = 0.708333

# %%
plt.style.use('ggplot')

plt.figure()

plt.subplot(1, 1, 1)
plt.plot([-ft, -ft], [bot, top], color='b')
plt.plot([ft, ft], [bot, top], color='b')
plt.plot([-ft, ft], [bot, bot], color='b')
plt.plot([-ft, ft], [top, top], color='b')

plt.scatter(plate['plate_x'], plate['plate_z'], s=3)

plt.plot([-ft, ft], [0, 0], color='b')
plt.plot([-ft, -ft], [0, -0.5], color='b')
plt.plot([ft, ft], [0, -0.5], color='b')
plt.plot([-ft, 0], [-0.5, -0.75], color='b')
plt.plot([ft, 0], [-0.5, -0.75], color='b')

plt.axis('off')

plt.xlim([-5, 5])
plt.ylim([-2, 6])


sns.jointplot(x='plate_x', y='plate_z', data=plate, kind='kde')

# %%
f, ax = plt.subplots(1)
for i in np.unique(target):
    mask = target == i
    plt.scatter(feats[mask, 0], feats[mask, 1], label=i)
ax.legend()
